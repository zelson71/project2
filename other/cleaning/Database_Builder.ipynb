# %%
import pandas as pd
import glob
from ipywidgets.embed import embed_minimal_html
import gmaps
import os

os.getcwd()
# Out:
# 'D:\\gitrepo\\project2\\wine_app'

# %% [markdown]
# ##### Create loop to convert 16 csv files to dataframes, apply utf-8 coding and put into list. Concatenate dataframes in list into one dataframe.

# %%
path = 'Resources/WE_data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, encoding = 'utf-8')
    li.append(df)

all_wines_df = pd.concat(li, axis=0, ignore_index=True,sort=True)

# %%
all_wines_df.index.name = ('ID')

# %%
all_wines_df.head(3)
# Out:
#     alcohol category  country  \
# ID
# 0      13.0    White  Austria
# 1      13.2      Red       US
# 2      15.0      Red    Italy
#
#                                           description  \
# ID
# 0   Heady, aromatic highlights of candied lemon pe...
# 1   This is among winemaker Cathy Corison's finest...
# 2   Enticing scents of spiced plum, pipe tobacco, ...
#
#                   designation  price  rating      region  \
# ID
# 0             Ried Kellerberg    NaN      96      Wachau
# 1             Kronos Vineyard  185.0      95  California
# 2   Vigneto Monte Sant'Urbano   80.0      94      Veneto
#
#                               subregion subsubregion  \
# ID
# 0                                   NaN          NaN
# 1                                  Napa   St. Helena
# 2   Amarone della Valpolicella Classico          NaN
#
#                                                 title  \
# ID
# 0   Pichler-Krutzler 2017 Ried Kellerberg Riesling...
# ...

# %%
all_wines_df = all_wines_df.dropna(subset=['region', 'subregion'], how='all')

# %%
all_wines_df = all_wines_df.dropna(subset=['price'],how='all')

# %%
all_wines_df = all_wines_df.dropna(subset=['country'],how='all')

# %%
all_wines_df
# Out:
#         alcohol category    country  \
# ID
# 1          13.2      Red         US
# 2          15.0      Red      Italy
# 3          14.1      Red         US
# 4          14.1    White         US
# 5          13.5    White    Austria
# ...         ...      ...        ...
# 248350      NaN      Red  Australia
# 248351     17.0    White         US
# 248352     14.3    White         US
# 248353     14.9      Red         US
# 248357      8.0    White    Germany
#
#                                               description  \
# ID
# 1       This is among winemaker Cathy Corison's finest...
# 2       Enticing scents of spiced plum, pipe tobacco, ...
# 3       Bright, crunchy red fruit effuses ripeness in ...
# 4       This white has an expert level of intensity an...
# 5       Yeast, celery and a hint of cream make for an ...
# ...                                                   ...
# 248350  Dense, richly fruited and superripe, this is a...
# ...

# %%
all_wines_df = all_wines_df.dropna(subset=['subregion', 'subsubregion'], how='all')

# %%
all_wines_df.head(3)
# Out:
#     alcohol category country  \
# ID
# 1      13.2      Red      US
# 2      15.0      Red   Italy
# 3      14.1      Red      US
#
#                                           description  \
# ID
# 1   This is among winemaker Cathy Corison's finest...
# 2   Enticing scents of spiced plum, pipe tobacco, ...
# 3   Bright, crunchy red fruit effuses ripeness in ...
#
#                   designation  price  rating      region  \
# ID
# 1             Kronos Vineyard  185.0      95  California
# 2   Vigneto Monte Sant'Urbano   80.0      94      Veneto
# 3               Foss Vineyard   62.0      94  California
#
#                               subregion          subsubregion  \
# ID
# 1                                  Napa            St. Helena
# 2   Amarone della Valpolicella Classico                   NaN
# 3                                Sonoma  Russian River Valley
#
#                                                 title  \
# ID
# 1   Corison 2015 Kronos Vineyard Cabernet Sauvigno...
# ...

# %%
all_wines_df = all_wines_df.dropna(subset=['alcohol'],how='all')

# %%
all_wines_df
# Out:
#         alcohol category country  \
# ID
# 1          13.2      Red      US
# 2          15.0      Red   Italy
# 3          14.1      Red      US
# 4          14.1    White      US
# 9          13.0      Red  France
# ...         ...      ...     ...
# 248342     15.2    White      US
# 248346     14.8      Red   Spain
# 248351     17.0    White      US
# 248352     14.3    White      US
# 248353     14.9      Red      US
#
#                                               description  \
# ID
# 1       This is among winemaker Cathy Corison's finest...
# 2       Enticing scents of spiced plum, pipe tobacco, ...
# 3       Bright, crunchy red fruit effuses ripeness in ...
# 4       This white has an expert level of intensity an...
# 9       A light touch of wood aging has given this win...
# ...                                                   ...
# 248342  This is a new winery for me, but one to watch....
# 248346  Aalto is one of Ribera's high flyers, and this...
# ...

# %%
all_wines_df = all_wines_df.dropna(subset=['varietal'],how='all')
all_wines_df = all_wines_df.dropna(subset=['vintage'],how='all')

# %%
all_wines_df
# Out:
#         alcohol category country  \
# ID
# 1          13.2      Red      US
# 2          15.0      Red   Italy
# 3          14.1      Red      US
# 4          14.1    White      US
# 9          13.0      Red  France
# ...         ...      ...     ...
# 248342     15.2    White      US
# 248346     14.8      Red   Spain
# 248351     17.0    White      US
# 248352     14.3    White      US
# 248353     14.9      Red      US
#
#                                               description  \
# ID
# 1       This is among winemaker Cathy Corison's finest...
# 2       Enticing scents of spiced plum, pipe tobacco, ...
# 3       Bright, crunchy red fruit effuses ripeness in ...
# 4       This white has an expert level of intensity an...
# 9       A light touch of wood aging has given this win...
# ...                                                   ...
# 248342  This is a new winery for me, but one to watch....
# 248346  Aalto is one of Ribera's high flyers, and this...
# ...

# %%
all_wines_df = all_wines_df.dropna(subset=['winery'],how='all')

# %%
all_wines_df['lat']=''
all_wines_df['lon']=''
all_wines_df
# Out:
#         alcohol category country  \
# ID
# 1          13.2      Red      US
# 2          15.0      Red   Italy
# 3          14.1      Red      US
# 4          14.1    White      US
# 9          13.0      Red  France
# ...         ...      ...     ...
# 248342     15.2    White      US
# 248346     14.8      Red   Spain
# 248351     17.0    White      US
# 248352     14.3    White      US
# 248353     14.9      Red      US
#
#                                               description  \
# ID
# 1       This is among winemaker Cathy Corison's finest...
# 2       Enticing scents of spiced plum, pipe tobacco, ...
# 3       Bright, crunchy red fruit effuses ripeness in ...
# 4       This white has an expert level of intensity an...
# 9       A light touch of wood aging has given this win...
# ...                                                   ...
# 248342  This is a new winery for me, but one to watch....
# 248346  Aalto is one of Ribera's high flyers, and this...
# ...

# %%
all_wines_df = pd.read_csv('needs_clean.csv')

# %%
import numpy as np
import requests
import json
import gmaps
from config import gkey
gmaps.configure(api_key=gkey)

# %% [markdown]
# ### I ran the below multiple time once I figured out that the region had some set to Other i did a find and replace with excel to set them to blank to pull them with
# ##### all_wines_df = all_wines_df.dropna(subset=['region'],how='all')

# %%
params = {"key": gkey}

for index, row in all_wines_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    city = row['region']
    state = row['country']

    params['address'] = f"{city},{state}"
    
    cities_lat_lng = requests.get(base_url, params=params)

    cities_lat_lng = cities_lat_lng.json()

    all_wines_df.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    all_wines_df.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-341-5609bf73b4a1> in <module>
#      13     cities_lat_lng = cities_lat_lng.json()
#      14
# ---> 15     all_wines_df.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
#      16     all_wines_df.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]
#
# IndexError: list index out of range

# %%
all_wines_df.to_csv('needs_clean.csv')

# %% [markdown]
# ## Did cleanup of columns removing the ID column befor the next step and then mad a copy of the file and saved it as been_cleaned

# %%
part_two = pd.read_csv('cleaned_no_ID.csv', encoding = 'utf-8')

# %%
part_two.index.name = ('ID')
part_two
# Out:
#         alcohol category country  \
# ID
# 0          13.2      Red      US
# 1          15.0      Red   Italy
# 2          14.1      Red      US
# 3          14.1    White      US
# 4          13.0      Red  France
# ...         ...      ...     ...
# 130367     14.1      Red      US
# 130368     14.7      Red      US
# 130369     14.1      Red      US
# 130370     13.7      Red      US
# 130371     14.7      Red      US
#
#                                               description  \
# ID
# 0       This is among winemaker Cathy Corison's finest...
# 1       Enticing scents of spiced plum, pipe tobacco, ...
# 2       Bright, crunchy red fruit effuses ripeness in ...
# 3       This white has an expert level of intensity an...
# 4       A light touch of wood aging has given this win...
# ...                                                   ...
# 130367  This sappy, sensational effort is bursting wit...
# 130368  This wine explores the gamy, cool-climate side...
# ...

# %%
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy import create_engine, func
from sqlalchemy.orm import Session
import sqlalchemy

# %%
engine = create_engine(
    'postgresql://postgres:postgres@localhost:5432/wines_db', echo=False, encoding='utf-8')
session = Session(engine)
if not database_exists(engine.url):
    create_database(engine.url)
conn = engine.connect()
session = Session(engine)

# %%
all_wines_df.to_sql("all_wines", index=True, if_exists='replace', con=engine)

# %%
part_two.to_csv('all_wine_lat_lng.csv', encoding = 'utf-8-sig')
